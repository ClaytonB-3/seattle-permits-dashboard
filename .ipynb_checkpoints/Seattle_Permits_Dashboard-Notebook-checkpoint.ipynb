# %%
import json
from urllib.request import urlopen

import dash
import dash_bootstrap_components as dbc
import dash_core_components as dcc
import dash_html_components as html
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.style as style
import missingno as msno
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
from dash.dependencies import Input, Output
import jupyterlab_dash
from jupyter_dash import JupyterDash

# %%
df = (pd.read_csv('Building_Permit_Map.csv'))
df.head()
# Out:
#     PermitNum  PermitClass PermitClassMapped PermitTypeDesc  \
# 0  6066117-DM          NaN               NaN            NaN
# 1  6066591-CN          NaN               NaN            NaN
# 2  6067546-DM          NaN               NaN            NaN
# 3  6068466-CN  Multifamily       Residential            New
# 4  6071661-CN          NaN               NaN            NaN
#
#                        Description  HousingUnits  HousingUnitsRemoved  \
# 0  DEMO EXISTING 8 UNIT APARTMENT.           NaN                  NaN
# 1             construct new garage           NaN                  NaN
# 2                      demo garage           NaN                  NaN
# 3       construct 1 unit townhouse           NaN                  NaN
# 4                         COM / TI           NaN                  NaN
#
#    HousingUnitsAdded  EstProjectCost StatusCurrent     OriginalAddress1  \
# 0                NaN             NaN        Closed      1701 NW IONE PL
# 1                NaN             NaN        Closed     5412 47TH AVE SW
# 2                NaN             NaN        Closed     5412 47TH AVE SW
# 3                NaN             NaN        Closed  701 S CLOVERDALE ST
# 4                NaN             NaN        Closed         500 17TH AVE
#
#   OriginalCity OriginalState  OriginalZip ContractorCompanyName  \
# 0      SEATTLE            WA      98107.0                   NaN
# 1      SEATTLE            WA      98136.0                   NaN
# 2      SEATTLE            WA      98136.0                   NaN
# 3      SEATTLE            WA          NaN                   NaN
# 4      SEATTLE            WA      98122.0                   NaN
#
#                                                 Link   Latitude   Longitude  \
# 0  https://cosaccela.seattle.gov/portal/customize...  47.666311 -122.379191
# 1  https://cosaccela.seattle.gov/portal/customize...  47.553566 -122.391967
# 2  https://cosaccela.seattle.gov/portal/customize...  47.553566 -122.391967
# 3  https://cosaccela.seattle.gov/portal/customize...        NaN         NaN
# 4  https://cosaccela.seattle.gov/portal/customize...  47.607061 -122.309671
#
#                       Location1
# 0  (47.66631064, -122.37919096)
# 1  (47.55356551, -122.39196664)
# 2  (47.55356551, -122.39196664)
# 3                           NaN
# 4   (47.6070606, -122.30967102)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148359 entries, 0 to 148358
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   PermitNum              148359 non-null  object
#  1   PermitClass            141956 non-null  object
#  2   PermitClassMapped      141956 non-null  object
#  3   PermitTypeDesc         139669 non-null  object
#  4   Description            148106 non-null  object
#  5   HousingUnits           15693 non-null   float64
#  6   HousingUnitsRemoved    68794 non-null   float64
#  7   HousingUnitsAdded      68794 non-null   float64
#  8   EstProjectCost         113598 non-null  float64
#  9   StatusCurrent          148359 non-null  object
#  10  OriginalAddress1       147984 non-null  object
#  11  OriginalCity           144123 non-null  object
#  12  OriginalState          143943 non-null  object
#  13  OriginalZip            140077 non-null  float64
#  14  ContractorCompanyName  26080 non-null   object
#  15  Link                   148359 non-null  object
#  16  Latitude               145644 non-null  float64
#  17  Longitude              145644 non-null  float64
#  18  Location1              145644 non-null  object
# dtypes: float64(7), object(12)
# memory usage: 21.5+ MB

# %% [markdown]
# ## Review Missing Data

# %%
df.isna().sum()
# Out:
# PermitNum                     0
# PermitClass                6403
# PermitClassMapped          6403
# PermitTypeDesc             8690
# Description                 253
# HousingUnits             132666
# HousingUnitsRemoved       79565
# HousingUnitsAdded         79565
# EstProjectCost            34761
# StatusCurrent                 0
# OriginalAddress1            375
# OriginalCity               4236
# OriginalState              4416
# OriginalZip                8282
# ContractorCompanyName    122279
# Link                          0
# Latitude                   2715
# Longitude                  2715
# Location1                  2715
# dtype: int64

# %%
df_missing = df.isna().sum().reset_index().rename(mapper={'index': 'column', 0: 'pct_missing'}, axis='columns')
df_missing['pct_missing'] = round((df_missing['pct_missing'] / 148359)*100, 2)
df_missing
# Out:
#                    column  pct_missing
# 0               PermitNum         0.00
# 1             PermitClass         4.32
# 2       PermitClassMapped         4.32
# 3          PermitTypeDesc         5.86
# 4             Description         0.17
# 5            HousingUnits        89.42
# 6     HousingUnitsRemoved        53.63
# 7       HousingUnitsAdded        53.63
# 8          EstProjectCost        23.43
# 9           StatusCurrent         0.00
# 10       OriginalAddress1         0.25
# 11           OriginalCity         2.86
# 12          OriginalState         2.98
# 13            OriginalZip         5.58
# 14  ContractorCompanyName        82.42
# 15                   Link         0.00
# 16               Latitude         1.83
# 17              Longitude         1.83
# 18              Location1         1.83

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Remove Uneeded Data and Columns
# I'm only interested in current permits for the dashboard, so I'll remove all rows where the status of the permit indicates it is not active.

# %%
not_active = ['Completed', 'Closed', 'Expired', 'Canceled', 'Withdrawn']
df_active = df[~df['StatusCurrent'].isin(not_active)]
cols = ['PermitNum', 'PermitTypeDesc',
        'HousingUnitsRemoved', 'HousingUnitsAdded', 'OriginalZip',
        'Longitude', 'Latitude', 'PermitClass', 'EstProjectCost', 'PermitClassMapped']
df_active = df_active[cols]

# %% [markdown]
# ### Remap Data
# Group all non-residential permit classes into one for visualizing.

# %%
permit_class_remap = {'Commercial': 'Non-Residential',
                      'Institutional': 'Non-Residential',
                      'Industrial': 'Non-Residential',
                      'Vacant Land': 'Non-Residential'}
df_active['PermitClassMapRes'] = (df_active['PermitClass']
                                  .replace(permit_class_remap))

# %% [markdown]
# ### Handle missing data
# 1. Remove rows with a missing zip code or location data as we will not be able to map them
# 2. Replace missing data in project cost with 'Unknown' as it will be displayed in a tooltop of the dashboard, but not calcualted.
# 3. Replace missing data in housing units added with zero, the most commone value in those colums by a wide margin.

# %%
df_active = df_active[~df_active['OriginalZip'].isna()]
df_active['OriginalZip'] = df_active['OriginalZip'].astype(int)
df_has_loc = df_active[~df_active['Latitude'].isna()]
df_has_loc = df_has_loc[df_has_loc.OriginalZip != 0]

# %%
(df_has_loc['HousingUnitsAdded'].value_counts()
   .sort_values(ascending=False).head())
# Out:
# 0.0    5138
# 1.0    1915
# 2.0     645
# 3.0     365
# 4.0     237
# Name: HousingUnitsAdded, dtype: int64

# %%
(df_has_loc['HousingUnitsRemoved'].value_counts()
    .sort_values(ascending=False).head())
# Out:
# 0.0    7778
# 1.0    1501
# 2.0     170
# 3.0      74
# 4.0      34
# Name: HousingUnitsRemoved, dtype: int64

# %%
# Fill null values
df_has_loc['EstProjectCost'].fillna('Unknown', inplace=True)
df_has_loc['HousingUnitsAdded'].fillna(0, inplace=True)
df_has_loc['HousingUnitsRemoved'].fillna(0, inplace=True)

# %% [markdown]
# ### Filter Based on Permit Type
# Looking at the frequency of each Permit Type I see that Addition/Alteration, New, and Demo and the most common and also types that really shape a city. For those reason we will remove all other permit types.

# %%
df_has_loc['PermitTypeDesc'].value_counts()
# Out:
# Addition/Alteration                        10207
# New                                         5320
# Demolition                                  1143
# Environmentally Critical Area Exemption      283
# Tenant Improvement Pre-Approval              236
# Temporary                                    227
# Tenant Improvment                            204
# Change of Use Only - No Construction         122
# Shoreline Exemption                           83
# Relief from Prohibition on Steep Slope        46
# Curb Cut                                      45
# Street Improvement Exception                  30
# Shoreline Permit Exemption                    18
# NONE                                          15
# ECA Small Project Waiver                      11
# Deconstruction                                 7
# Relocation                                     6
# Modification to Submittal Requirements         6
# Name: PermitTypeDesc, dtype: int64

# %%
# Filter to just Additions, New, and Demo permits
df_has_loc = df_has_loc[df_has_loc['PermitTypeDesc'].isin(
                                ['Addition/Alteration', 'New', 'Demolition'])]
# Check final nulls
df_has_loc.isna().sum()
# Out:
# PermitNum               0
# PermitTypeDesc          0
# HousingUnitsRemoved     0
# HousingUnitsAdded       0
# OriginalZip             0
# Longitude               0
# Latitude                0
# PermitClass            22
# EstProjectCost          0
# PermitClassMapped      22
# PermitClassMapRes      22
# dtype: int64

# %%
# Remove 22 rows with missing class
df_has_loc = df_has_loc.dropna()

# %%
df_has_loc.head()
# Out:
#       PermitNum       PermitTypeDesc  HousingUnitsRemoved  HousingUnitsAdded  \
# 189  6355402-CN  Addition/Alteration                  0.0                0.0
# 213  6412737-CN  Addition/Alteration                  0.0                0.0
# 232  6486380-CN                  New                  0.0                0.0
# 263  6582805-CN  Addition/Alteration                  0.0                0.0
# 267  6604359-CN  Addition/Alteration                  0.0                0.0
#
#     OriginalZip   Longitude   Latitude           PermitClass EstProjectCost  \
# 189       98105 -122.299266  47.661539            Commercial        Unknown
# 213       98101 -122.325216  47.611599            Commercial        Unknown
# 232       98115 -122.327034  47.675753  Single Family/Duplex        Unknown
# 263       98115 -122.318608  47.685100  Single Family/Duplex        Unknown
# 267       98104 -122.333907  47.603316           Multifamily        Unknown
#
#     PermitClassMapped     PermitClassMapRes
# 189   Non-Residential       Non-Residential
# 213   Non-Residential       Non-Residential
# 232       Residential  Single Family/Duplex
# 263       Residential  Single Family/Duplex
# 267       Residential           Multifamily

# %%
# Convert zips to strings
df_has_loc = df_has_loc.astype(dtype={'OriginalZip': 'str'})

# %%
# Make list of unique zips for drop down
unique_zips = df_has_loc['OriginalZip'].drop_duplicates().sort_values().tolist()

# %% [markdown]
# ### Create Dataframes of Permit Class and Type breakdowns per zip
# For the visualization I want to be able to see the breakdown of the type/class of each permit for each zip code based on the user's selection. In order to support this I will create a data frame with this info for types and for classes.
#
# 1. Group by zip and type/class
# 2. Count number of type/class per zip
# 3. Add column for total number of permits in each zip
# 4. Add column calculating percent of each type/class per zip

# %%
# Group and count permit types per Zip for charts
type_grouper = (df_has_loc.groupby(['OriginalZip',
                                   'PermitTypeDesc'])['PermitNum']
                .count().reset_index())
type_mapper = {'PermitNum': 'PermitTypeCount',
               'PermitClassMapRes': 'PermitClass'}
type_grouper.rename(mapper=type_mapper, axis='columns', inplace=True)

# %%
# Group and count permit type per Zip
zip_type_g = (df_has_loc.groupby(['OriginalZip',
                                   'PermitTypeDesc'])['PermitNum']
                .count().reset_index())
zip_type_g = zip_type_g.rename(mapper={'PermitNum': 'PermitTypeCount'},
                               axis='columns')

# %%
# Count total type permits per zip
zip_t_g = zip_type_g.groupby('OriginalZip')['PermitTypeCount'].sum().reset_index()
zip_t_g = zip_t_g.rename(mapper={'PermitTypeCount': 'TotalTypePermit'},
                               axis='columns')

# %%
zip_type_g = zip_type_g.merge(zip_t_g, how='left', on='OriginalZip')

# %%
# calc percent of each type permit per zip
zip_type_g['pct_permit_type'] = round((zip_type_g['PermitTypeCount'] 
                                 / zip_type_g['TotalTypePermit']) ,4)
zip_type_g
# Out:
#    OriginalZip       PermitTypeDesc  PermitTypeCount  TotalTypePermit  \
# 0        98101  Addition/Alteration              356              439
# 1        98101           Demolition               15              439
# 2        98101                  New               68              439
# 3        98102  Addition/Alteration              298              484
# 4        98102           Demolition               35              484
# ..         ...                  ...              ...              ...
# 80       98195  Addition/Alteration               41               50
# 81       98195                  New                9               50
# 82       98199  Addition/Alteration              404              583
# 83       98199           Demolition               34              583
# 84       98199                  New              145              583
#
#     pct_permit_type
# 0            0.8109
# 1            0.0342
# 2            0.1549
# 3            0.6157
# 4            0.0723
# ..              ...
# 80           0.8200
# 81           0.1800
# 82           0.6930
# 83           0.0583
# 84           0.2487
#
# [85 rows x 5 columns]

# %%
# Group and count permit type per Zip
zip_class_g = (df_has_loc.groupby(['OriginalZip',
                                   'PermitClassMapRes'])['PermitNum']
                .count().reset_index())
zip_class_g = zip_class_g.rename(mapper={'PermitNum': 'PermitClassCount'},
                               axis='columns')

# %%
# Count total class permits per zip and merge
zip_c_g = (zip_class_g.groupby('OriginalZip')['PermitClassCount']
           .sum().reset_index())
zip_c_g = zip_c_g.rename(mapper={'PermitClassCount': 'TotalClassPermit'},
                               axis='columns')
zip_class_g = zip_class_g.merge(zip_c_g, how='left', on='OriginalZip')

# %%
# calc percent of each class permit per zip
zip_class_g['pct_permit_class'] = round((zip_class_g['PermitClassCount'] 
                                 / zip_class_g['TotalClassPermit']) ,4)
zip_class_g
# Out:
#    OriginalZip     PermitClassMapRes  PermitClassCount  TotalClassPermit  \
# 0        98101           Multifamily                78               439
# 1        98101       Non-Residential               360               439
# 2        98101  Single Family/Duplex                 1               439
# 3        98102           Multifamily               205               484
# 4        98102       Non-Residential               100               484
# ..         ...                   ...               ...               ...
# 78       98195           Multifamily                 1                50
# 79       98195       Non-Residential                49                50
# 80       98199           Multifamily                40               583
# 81       98199       Non-Residential                66               583
# 82       98199  Single Family/Duplex               477               583
#
#     pct_permit_class
# 0             0.1777
# 1             0.8200
# 2             0.0023
# 3             0.4236
# 4             0.2066
# ..               ...
# 78            0.0200
# 79            0.9800
# 80            0.0686
# 81            0.1132
# 82            0.8182
#
# [83 rows x 5 columns]

# %% [markdown]
# ### Zip codes with highest percentage of each type and class of permit

# %%
zip_type_g[(zip_type_g['PermitTypeDesc']=='Addition/Alteration') & 
           (zip_type_g['TotalTypePermit'] > 20)].sort_values(
                       'pct_permit_type', ascending=False).head()
# Out:
#    OriginalZip       PermitTypeDesc  PermitTypeCount  TotalTypePermit  \
# 60       98134  Addition/Alteration              193              226
# 80       98195  Addition/Alteration               41               50
# 69       98146  Addition/Alteration               82              100
# 45       98121  Addition/Alteration              207              255
# 0        98101  Addition/Alteration              356              439
#
#     pct_permit_type
# 60           0.8540
# 80           0.8200
# 69           0.8200
# 45           0.8118
# 0            0.8109

# %%
zip_type_g[(zip_type_g['PermitTypeDesc']=='Demolition') & 
           (zip_type_g['TotalTypePermit'] > 20)].sort_values(
                       'pct_permit_type', ascending=False).head()
# Out:
#    OriginalZip PermitTypeDesc  PermitTypeCount  TotalTypePermit  \
# 19       98107     Demolition               76              674
# 7        98103     Demolition              132             1314
# 13       98105     Demolition               83              888
# 31       98115     Demolition              105             1149
# 37       98117     Demolition               84              967
#
#     pct_permit_type
# 19           0.1128
# 7            0.1005
# 13           0.0935
# 31           0.0914
# 37           0.0869

# %%
zip_type_g[(zip_type_g['PermitTypeDesc']=='New') & 
           (zip_type_g['TotalTypePermit'] > 20)].sort_values(
                       'pct_permit_type', ascending=False).head()
# Out:
#    OriginalZip PermitTypeDesc  PermitTypeCount  TotalTypePermit  \
# 17       98106            New              323              618
# 68       98144            New              399              876
# 41       98118            New              531             1167
# 23       98108            New              272              636
# 79       98178            New               56              131
#
#     pct_permit_type
# 17           0.5227
# 68           0.4555
# 41           0.4550
# 23           0.4277
# 79           0.4275

# %%
zip_class_g[(zip_class_g['PermitClassMapRes']=='Multifamily') & 
           (zip_class_g['TotalClassPermit'] > 20)].sort_values(
                       'pct_permit_class', ascending=False).head()
# Out:
#    OriginalZip PermitClassMapRes  PermitClassCount  TotalClassPermit  \
# 3        98102       Multifamily               205               484
# 64       98144       Multifamily               272               876
# 47       98122       Multifamily               226               892
# 45       98121       Multifamily                63               255
# 18       98107       Multifamily               165               674
#
#     pct_permit_class
# 3             0.4236
# 64            0.3105
# 47            0.2534
# 45            0.2471
# 18            0.2448

# %%
zip_class_g[(zip_class_g['PermitClassMapRes']=='Single Family/Duplex') & 
           (zip_class_g['TotalClassPermit'] > 20)].sort_values(
                       'pct_permit_class', ascending=False).head()
# Out:
#    OriginalZip     PermitClassMapRes  PermitClassCount  TotalClassPermit  \
# 77       98178  Single Family/Duplex               122               131
# 69       98146  Single Family/Duplex                92               100
# 74       98177  Single Family/Duplex               191               211
# 82       98199  Single Family/Duplex               477               583
# 32       98115  Single Family/Duplex               912              1149
#
#     pct_permit_class
# 77            0.9313
# 69            0.9200
# 74            0.9052
# 82            0.8182
# 32            0.7937

# %%
zip_class_g[(zip_class_g['PermitClassMapRes']=='Non-Residential') & 
           (zip_class_g['TotalClassPermit'] > 20)].sort_values(
                       'pct_permit_class', ascending=False).head()
# Out:
#    OriginalZip PermitClassMapRes  PermitClassCount  TotalClassPermit  \
# 60       98134   Non-Residential               225               226
# 79       98195   Non-Residential                49                50
# 1        98101   Non-Residential               360               439
# 46       98121   Non-Residential               192               255
# 10       98104   Non-Residential               290               393
#
#     pct_permit_class
# 60            0.9956
# 79            0.9800
# 1             0.8200
# 46            0.7529
# 10            0.7379

# %%
# Dash app layout
bg_color = '#f0f8ff'
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.FLATLY])


app.layout = dbc.Container([
    dbc.Row(
        dbc.Col(
            html.H1("Active Construction Permits in Seattle"),
            style={'text-align': 'center'}), style={'margin-bottom': 25}
            ),
    dbc.Row(
        [dbc.Col(dcc.Slider(id="type_or_class",
                           min=0,
                           max=1,
                           step=1,
                             marks=
                              {0: "Class",
                               1: "Type"},
                             value=0),
                width={'size': 4, 'offset': 0, 'order': 1}
                ),
         dbc.Col(dcc.Slider(id="pct_or_total",
                           min=0,
                           max=1,
                           step=1,
                             marks=
                              {0: "Percent",
                               1: "Total"},
                             value=0),
                 width={'size': 4, 'offset': 2, 'order': 2})]),
    dbc.Row([
        dbc.Col([dcc.Dropdown(id="slct_zip",
                             options=[{'label': zip,
                                       'value': zip} for zip in unique_zips
                                      ],
                             multi=True,
                             value=[],
                             placeholder='Select Zip Codes, All by Default'),
                dcc.Graph(id='sea_permit_map', figure={})],
                width=4),
        dbc.Col([  # second columns for graphs
                dcc.Graph(id='horizontal_bar_type', figure={}),
                dcc.Graph(id='horizontal_bar_class', figure={}),
                ], width=8),
        ]),
    dbc.Row(
        dbc.Col(
            html.H5("Datasource: https://data.seattle.gov/"),
            style={'text-align': 'left'})
            ),
    dbc.Row(
        dbc.Col(
            html.H5("Dashboard by Clayton Brock"),
            style={'text-align': 'left'})
            ),
], fluid=True, style={'backgroundColor': bg_color})

# %%
@app.callback(
    [Output(component_id='sea_permit_map', component_property='figure'),
     Output(component_id='horizontal_bar_class', component_property='figure'),
     Output(component_id='horizontal_bar_type', component_property='figure')],
    [Input(component_id='type_or_class', component_property='value'),
     Input(component_id='slct_zip', component_property='value'),
     Input(component_id='pct_or_total', component_property='value')]
)
def update_map(type_class, slct_zip, pct_total):

    df1 = df_has_loc.copy()
    # df2 = type_grouper.copy()  # for filtering on type and class
    df3 = zip_type_g.copy()
    df4 = zip_class_g.copy()

# -------MAP---------------------------
    if bool(slct_zip) is False:
        print('no zip')
    else:
        df1 = df1[df1['OriginalZip'].isin(slct_zip)] 

    if type_class == 0:   #Color map by class
        fig_map = px.scatter_mapbox(
                df1,
                lon='Longitude',
                lat='Latitude',
                labels={'PermitTypeDesc': 'Permit Type',
                        'PermitNum': 'Permit Number',
                        'OriginalZip': 'Zip Code',
                        'PermitClassMapRes': 'Permit Class'
                        },
                hover_data={'Longitude': False,
                            'Latitude': False,
                            'OriginalZip': True,
                            'PermitNum': True,
                            'PermitTypeDesc': True,
                            'PermitClassMapRes': True},
                mapbox_style='open-street-map',
                color='PermitClassMapRes',
                color_discrete_map={"Single Family/Duplex": '#e9a3c9',
                                    'Multifamily': '#c51b7d',
                                    'Non-Residential': '#4d9221'},
                zoom=10,
                height=900,
                width=700)
    elif type_class == 1:   # Color map by type
        fig_map = px.scatter_mapbox(
                df1,
                lon='Longitude',
                lat='Latitude',
                hover_data={'Longitude': False,
                            'Latitude': False,
                            'OriginalZip': True,
                            'PermitNum': True,
                            'PermitTypeDesc': True,
                            'PermitClassMapRes': True},
                mapbox_style='open-street-map',
                color='PermitTypeDesc',
                labels={'PermitTypeDesc': 'Permit Type',
                        'PermitNum': 'Permit Number',
                        'OriginalZip': 'Zip Code',
                        'PermitClassMapRes': 'Permit Class'
                        },
                color_discrete_map={"New": '#2166ac',
                                    'Demolition': '#b2182b',
                                    'Addition/Alteration': '#67a9cf'},
                zoom=10,
                height=900,
                width=700)


    fig_map.update_traces(marker=dict(size=4))
    fig_map.update_layout(showlegend=True,
                       legend={'orientation': "h",
                               'yanchor': "bottom",
                               'y': 1.02,
                               'xanchor': "right",
                               'x': 1,
                               'title': '',
                               'itemsizing': 'constant',
                               'itemwidth': 30},
                         paper_bgcolor=bg_color)
    
# ------------------CLASS BAR CHART___________________   

    if pct_total == 1: # TOTAL TOTAL
        if bool(slct_zip) is False:
            fig_class = px.bar(df4, x="PermitClassCount", y="OriginalZip",
                               color='PermitClassMapRes', orientation='h',
                               labels={'PermitClassCount': 'Zip Class Total',
                                       'TotalClassPermit': 'Zip Permit Total',
                                       'OriginalZip': 'Zip Code',
                                       'PermitClassMapRes': 'Permit Class',
                                       'pct_permit_class': 'Zip Class Percent'
                                       },
                               hover_data=["PermitClassMapRes",
                               "PermitClassCount",
                               'TotalClassPermit',
                               'pct_permit_class'],
                                height=400,
                                title='Total of Each Permit Class Per Zip Code',
                                color_discrete_map={
                                    "Single Family/Duplex": '#e9a3c9',
                                    'Multifamily': '#c51b7d',
                                    'Non-Residential': '#4d9221'}
                              )
            #fig_class.update_layout(marker={'colorbar':{'showticklabels':False}})
            fig_class.update_yaxes({'showticklabels': False,
                                    'title': {'text': 'Zip Code'}})
            fig_class.update_xaxes({'showticklabels': True,
                                    'title': {'text': ''}})

        else:
            df4 = df4[df4['OriginalZip'].isin(slct_zip)]
            fig_class = px.bar(df4, x="PermitClassCount", y="OriginalZip",
                               color='PermitClassMapRes', orientation='h',
                               labels={'PermitClassCount': 'Zip Class Total',
                                       'TotalClassPermit': 'Zip Permit Total',
                                       'OriginalZip': 'Zip Code',
                                       'PermitClassMapRes': 'Permit Class',
                                       'pct_permit_class': 'Zip Class Percent'
                                       },
                               hover_data=["PermitClassMapRes",
                               "PermitClassCount",
                               'TotalClassPermit',
                               'pct_permit_class'],
                                height=400,
                                title='Total of Each Permit Class Per Zip Code',
                                color_discrete_map={
                                    "Single Family/Duplex": '#e9a3c9',
                                    'Multifamily': '#c51b7d',
                                    'Non-Residential': '#4d9221'}
                              )
            fig_class.update_yaxes({'showticklabels': True,
                                    'title': {'text': 'Zip Code'}})
            fig_class.update_xaxes({'showticklabels': True,
                                    'title': {'text': ''}})

    elif pct_total == 0: # PERCENT
        if bool(slct_zip) is False:
            fig_class = px.bar(df4, x="pct_permit_class", y="OriginalZip",
                               color='PermitClassMapRes', orientation='h',
                               labels={'PermitClassCount': 'Zip Class Total',
                                       'TotalClassPermit': 'Zip Permit Total',
                                       'OriginalZip': 'Zip Code',
                                       'PermitClassMapRes': 'Permit Class',
                                       'pct_permit_class': 'Zip Class Percent'
                                       },
                               hover_data=["PermitClassMapRes",
                               "PermitClassCount",
                               'TotalClassPermit'],
                                height=400,
                                title='Percent of Each Permit Class Per Zip Code',
                                color_discrete_map={
                                    "Single Family/Duplex": '#e9a3c9',
                                    'Multifamily': '#c51b7d',
                                    'Non-Residential': '#4d9221'}
                              )
            #fig_class.update_layout(marker={'colorbar':{'showticklabels':False}})
            fig_class.update_yaxes({'showticklabels': False,
                                    'title': {'text': 'Zip Code'}})
            fig_class.update_xaxes({'showticklabels': True,
                                    'title': {'text': ''},
                                    'tickformat': '%'})

        else:
            df4 = df4[df4['OriginalZip'].isin(slct_zip)]
            fig_class = px.bar(df4, x="pct_permit_class", y="OriginalZip",
                               color='PermitClassMapRes', orientation='h',
                               labels={'PermitClassCount': 'Zip Class Total',
                                       'TotalClassPermit': 'Zip Permit Total',
                                       'OriginalZip': 'Zip Code',
                                       'PermitClassMapRes': 'Permit Class',
                                       'pct_permit_class': 'Zip Class Percent'
                                       },
                               hover_data=["PermitClassMapRes",
                               "PermitClassCount",
                               'TotalClassPermit'],
                                height=400,
                                title='Percent of Each Permit Class Per Zip Code',
                                color_discrete_map={
                                    "Single Family/Duplex": '#e9a3c9',
                                    'Multifamily': '#c51b7d',
                                    'Non-Residential': '#4d9221'}
                              )
            fig_class.update_yaxes({'showticklabels': True,
                                    'title': {'text': 'Zip Code'}})
            fig_class.update_xaxes({'showticklabels': True,
                                    'title': {'text': ''},
                                    'tickformat': '%'})
    fig_class.update_layout(legend={
                                        'orientation': "h",
                                        'yanchor': "bottom",
                                        'y': 1.02,
                                        'xanchor': "left",
                                        'x': 0,
                                        'title': ''
                                            },
                            paper_bgcolor=bg_color
                                    )

 # -----------------TYPE BAR CHART-------------------
        
    if pct_total == 1:     # TOTAL
        if bool(slct_zip) is False:
            fig_type = px.bar(df3, x="PermitTypeCount", y="OriginalZip",
                              color='PermitTypeDesc', orientation='h',
                              labels={'PermitTypeDesc': 'Permit Type',
                                       'TotalTypePermit': 'Zip Permit Total',
                                       'OriginalZip': 'Zip Code',
                                       'PermitTypeCount': 'Zip Type Total',
                                       'pct_permit_type': 'Zip Type Percent'
                                       },
                              hover_data=["PermitTypeDesc", "PermitTypeCount",
                                          'TotalTypePermit'],
                              height=400,
                              title='Total of Each Permit Type Per Zip Code',
                              color_discrete_map={"New": '#2166ac',
                                                  'Demolition': '#b2182b',
                                                  'Addition/Alteration': '#67a9cf'})
            fig_type.update_yaxes({'showticklabels': False,
                                    'title': {'text': 'Zip Code'}})
            fig_type.update_xaxes({'showticklabels': True,
                                    'title': {'text': ''}})

        else:
            df3 = df3[df3['OriginalZip'].isin(slct_zip)]
            fig_type = px.bar(df3, x="PermitTypeCount", y="OriginalZip",
                              color='PermitTypeDesc', orientation='h',
                              labels={'PermitTypeDesc': 'Permit Type',
                                       'TotalTypePermit': 'Zip Permit Total',
                                       'OriginalZip': 'Zip Code',
                                       'PermitTypeCount': 'Zip Type Total',
                                       'pct_permit_type': 'Zip Type Percent'
                                       },
                              hover_data=["PermitTypeDesc", "PermitTypeCount",
                                          'TotalTypePermit'],
                              height=400,
                              title='Total of Each Permit Type Per Zip Code',
                              color_discrete_map={"New": '#2166ac',
                                                  'Demolition': '#b2182b',
                                                  'Addition/Alteration': '#67a9cf'})
            fig_type.update_yaxes({'showticklabels': True,
                                    'title': {'text': 'Zip Code'}})
            fig_type.update_xaxes({'showticklabels': True,
                                    'title': {'text': ''}})

    if pct_total == 0:     # PERCENT PERCENT 
        if bool(slct_zip) is False:
            fig_type = px.bar(df3, x="pct_permit_type", y="OriginalZip",
                              color='PermitTypeDesc', orientation='h',
                              labels={'PermitTypeDesc': 'Permit Type',
                                       'TotalTypePermit': 'Zip Permit Total',
                                       'OriginalZip': 'Zip Code',
                                       'PermitTypeCount': 'Zip Type Total',
                                       'pct_permit_type': 'Zip Type Percent'
                                       },
                              hover_data=["PermitTypeDesc", "PermitTypeCount",
                                          'TotalTypePermit'],
                              height=400,
                              title='Percent of Each Permit Type Per Zip Code',
                              color_discrete_map={"New": '#2166ac',
                                                  'Demolition': '#b2182b',
                                                  'Addition/Alteration': '#67a9cf'})
            fig_type.update_yaxes({'showticklabels': False,
                                    'title': {'text': 'Zip Code'}})
            fig_type.update_xaxes({'showticklabels': True,
                                    'title': {'text': ''},
                                    'tickformat': '%'})

        else:
            df3 = df3[df3['OriginalZip'].isin(slct_zip)]
            fig_type = px.bar(df3, x="pct_permit_type", y="OriginalZip",
                              color='PermitTypeDesc', orientation='h',
                              labels={'PermitTypeDesc': 'Permit Type',
                                       'TotalTypePermit': 'Zip Permit Total',
                                       'OriginalZip': 'Zip Code',
                                       'PermitTypeCount': 'Zip Type Total',
                                       'pct_permit_type': 'Zip Type Percent'
                                       },
                              hover_data=["PermitTypeDesc", "PermitTypeCount",
                                          'TotalTypePermit'],
                              height=400,
                              title='Percent of Each Permit Type Per Zip Code',
                              color_discrete_map={"New": '#2166ac',
                                                  'Demolition': '#b2182b',
                                                  'Addition/Alteration': '#67a9cf'})
            fig_type.update_yaxes({'showticklabels': True,
                                    'title': {'text': 'Zip Code'}})
            fig_type.update_xaxes({'showticklabels': True,
                                    'title': {'text': ''},
                                    'tickformat': '%'})
    fig_type.update_layout(legend={
                                'orientation': "h",
                                'yanchor': "bottom",
                                'y': 1.02,
                                'xanchor': "left",
                                'x': 0,
                                'title': ''
                                    },
                            paper_bgcolor=bg_color
                            )

    
    

    return (fig_map, fig_class, fig_type)

# %%
#app.run_server(debug=True, use_reloader=False)
